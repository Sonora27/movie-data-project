# %%
import requests
import sys
import numpy as np
import time
import pandas as pd
from bs4 import BeautifulSoup
#time.sleep(1)

# %%
def get_links(year):
    """returns a list of link suffixes that connect to every movie in the
    boxofficemojo page for the given year"""
    page = requests.get("https://www.boxofficemojo.com/year/{}/".format(year))
    soup = BeautifulSoup(page.content, 'html.parser')
    if page.status_code >=400:
        return [page.status_code,"https://www.boxofficemojo.com/year/{}/".format(year)]
    links = soup.select(".a-text-left.mojo-field-type-release.mojo-cell-wide a")
    return links

# %%
def cash_str_to_int(string):
    #takes string containing a number with a symbol at the front and returns the int
    return int(string[1:].replace(",",""))

# %%
def make_movie_dict(links):
    """accepts a list of link suffixes and returns a dictionary that
    has a key for each link. The value of each item is also a dictionary
    containing keys
                    domestic, international, worldwide, budget, genres, and title,
    with types      float     float          float      float   list[strs]   str
    
    if an int is missing its replaced with none and if genres is missing it is
    replaced with an empty list
    """
    movie_dict = {}
    for link in links:
        time.sleep(np.random.random())
        current = requests.get("https://www.boxofficemojo.com" + link["href"])
        currysoup = BeautifulSoup(current.content, "html.parser")
        title = currysoup.find("h1").text
        print("scraping ", title)
        try:
            budget = cash_str_to_int(currysoup.find(text="Budget").next_element.text)
        except AttributeError:
            budget = None
        grossli = currysoup.select(".a-section.a-spacing-none.mojo-performance-summary-table .a-section.a-spacing-none")
        grosses = []
        for i in grossli:
            try:
                grosses.append(cash_str_to_int(i.select(".money")[0].text))
            except IndexError:
                grosses.append(None)
        try:
            genres = list(currysoup.select(".a-section.a-spacing-none.mojo-summary-values.mojo-hidden-from-mobile")[0])[6].find_all("span")[1].text.split()
        except IndexError:
            genres = []
        movie_dict[link["href"]] = {"domestic":grosses[0],
                                    "international":grosses[1],
                                    "worldwide":grosses[2],
                                    "budget":budget,
                                    "genres":genres,
                                    "title":title
                                   }
        print(movie_dict[link["href"]])
        #uncomment the below to see only one pull
        #return(movie_dict)
    return movie_dict

# %%
links_2019 = get_links(2005)
movie_dict_2019 = make_movie_dict(links_2019)
# Out:
# scraping  Star Wars: Episode III - Revenge of the Sith
# {'domestic': 380270577, 'international': 488081953, 'worldwide': 868352530, 'budget': 113000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'], 'title': 'Star Wars: Episode III - Revenge of the Sith'}
# scraping  Harry Potter and the Goblet of Fire
# {'domestic': 290013036, 'international': 605908000, 'worldwide': 895921036, 'budget': 150000000, 'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'], 'title': 'Harry Potter and the Goblet of Fire'}
# scraping  War of the Worlds
# {'domestic': 234280354, 'international': 369592765, 'worldwide': 603873119, 'budget': 132000000, 'genres': ['Adventure', 'Sci-Fi', 'Thriller'], 'title': 'War of the Worlds'}
# scraping  The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# {'domestic': 291710957, 'international': 453302158, 'worldwide': 745013115, 'budget': 180000000, 'genres': ['Adventure', 'Family', 'Fantasy'], 'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'}
# scraping  Wedding Crashers
# {'domestic': 209255921, 'international': 79211724, 'worldwide': 288467645, 'budget': 40000000, 'genres': ['Comedy', 'Romance'], 'title': 'Wedding Crashers'}
# scraping  Charlie and the Chocolate Factory
# {'domestic': 206459076, 'international': 268509687, 'worldwide': 474968763, 'budget': 150000000, 'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical'], 'title': 'Charlie and the Chocolate Factory'}
# scraping  Batman Begins
# {'domestic': 205343774, 'international': 166510009, 'worldwide': 371853783, 'budget': 150000000, 'genres': ['Action', 'Adventure'], 'title': 'Batman Begins'}
# scraping  Madagascar
# {'domestic': 193595521, 'international': 348468325, 'worldwide': 542063846, 'budget': None, 'genres': ['219', 'days/31', 'weeks'], 'title': 'Madagascar'}
# scraping  Mr. & Mrs. Smith
# {'domestic': 186336279, 'international': 300951367, 'worldwide': 487287646, 'budget': 110000000, 'genres': ['Action', 'Comedy', 'Crime', 'Thriller'], 'title': 'Mr. & Mrs. Smith'}
# scraping  Hitch
# {'domestic': 179495555, 'international': 192098655, 'worldwide': 371594210, 'budget': 70000000, 'genres': ['Comedy', 'Romance'], 'title': 'Hitch'}
# scraping  King Kong
# {'domestic': 218080025, 'international': 344283424, 'worldwide': 562363449, 'budget': 207000000, 'genres': ['Action', 'Adventure', 'Drama', 'Romance'], 'title': 'King Kong'}
# scraping  The Longest Yard
# {'domestic': 158119460, 'international': 33347096, 'worldwide': 191466556, 'budget': 82000000, 'genres': ['Comedy', 'Crime', 'Sport'], 'title': 'The Longest Yard'}
# scraping  Fantastic Four
# {'domestic': 154696080, 'international': 178839854, 'worldwide': 333535934, 'budget': 100000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'], 'title': 'Fantastic Four'}
# scraping  Meet the Fockers
# {'domestic': 279261160, 'international': 243396776, 'worldwide': 522657936, 'budget': 80000000, 'genres': ['Comedy', 'Romance'], 'title': 'Meet the Fockers'}
# scraping  Chicken Little
# {'domestic': 135386665, 'international': 179046172, 'worldwide': 314432837, 'budget': 150000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi'], 'title': 'Chicken Little'}
# scraping  Robots
# {'domestic': 128200012, 'international': 134311478, 'worldwide': 262511490, 'budget': 75000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi'], 'title': 'Robots'}
# scraping  The Pacifier
# {'domestic': 113086868, 'international': 85550000, 'worldwide': 198636868, 'budget': 56000000, 'genres': ['Action', 'Comedy', 'Drama', 'Family'], 'title': 'The Pacifier'}
# scraping  The 40-Year-Old Virgin
# {'domestic': 109449237, 'international': 67929408, 'worldwide': 177378645, 'budget': 26000000, 'genres': ['Comedy', 'Romance'], 'title': 'The 40-Year-Old Virgin'}
# scraping  Million Dollar Baby
# {'domestic': 100492203, 'international': 116271443, 'worldwide': 216763646, 'budget': 30000000, 'genres': ['Drama', 'Sport'], 'title': 'Million Dollar Baby'}
# scraping  Walk the Line
# {'domestic': 119519402, 'international': 67278584, 'worldwide': 186797986, 'budget': 28000000, 'genres': ['Biography', 'Drama', 'Music', 'Romance'], 'title': 'Walk the Line'}
# scraping  Flightplan
# {'domestic': 89707299, 'international': 133680000, 'worldwide': 223387299, 'budget': None, 'genres': ['465', 'days/66', 'weeks'], 'title': 'Flightplan'}
# scraping  Saw II
# {'domestic': 87039965, 'international': 60708540, 'worldwide': 147748505, 'budget': 4000000, 'genres': ['Action', 'Crime', 'Fantasy', 'Horror', 'Mystery', 'Romance'], 'title': 'Saw II'}
# scraping  Monster-in-Law
# {'domestic': 82931301, 'international': 72526026, 'worldwide': 155457327, 'budget': 43000000, 'genres': ['Comedy', 'Romance'], 'title': 'Monster-in-Law'}
# scraping  Are We There Yet?
# {'domestic': 82674398, 'international': 15244265, 'worldwide': 97918663, 'budget': 32000000, 'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance'], 'title': 'Are We There Yet?'}
# scraping  The Dukes of Hazzard
# {'domestic': 80270227, 'international': 30799288, 'worldwide': 111069515, 'budget': 50000000, 'genres': ['Comedy'], 'title': 'The Dukes of Hazzard'}
# scraping  The Aviator
# {'domestic': 102610330, 'international': 111109612, 'worldwide': 213719942, 'budget': 110000000, 'genres': ['Biography', 'Drama'], 'title': 'The Aviator'}
# scraping  March of the Penguins
# {'domestic': 77437223, 'international': 49955470, 'worldwide': 127392693, 'budget': None, 'genres': ['2,506', 'theaters'], 'title': 'March of the Penguins'}
# scraping  The Ring Two
# {'domestic': 76231249, 'international': 87764700, 'worldwide': 163995949, 'budget': None, 'genres': ['289', 'days/41', 'weeks'], 'title': 'The Ring Two'}
# scraping  Constantine
# {'domestic': 75976178, 'international': 154908550, 'worldwide': 230884728, 'budget': 100000000, 'genres': ['Action', 'Fantasy', 'Horror', 'Mystery'], 'title': 'Constantine'}
# scraping  The Exorcism of Emily Rose
# {'domestic': 75072454, 'international': 70094350, 'worldwide': 145166804, 'budget': 19000000, 'genres': ['Drama', 'Horror', 'Thriller'], 'title': 'The Exorcism of Emily Rose'}
# scraping  Four Brothers
# {'domestic': 74494381, 'international': 17880293, 'worldwide': 92374674, 'budget': 45000000, 'genres': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'], 'title': 'Four Brothers'}
# scraping  Sin City
# {'domestic': 74103820, 'international': 84630000, 'worldwide': 158733820, 'budget': 40000000, 'genres': ['Crime', 'Thriller'], 'title': 'Sin City'}
# scraping  The Interpreter
# {'domestic': 72708161, 'international': 90236762, 'worldwide': 162944923, 'budget': 80000000, 'genres': ['Crime', 'Mystery', 'Thriller'], 'title': 'The Interpreter'}
# scraping  Guess Who
# {'domestic': 68915888, 'international': 34205578, 'worldwide': 103121466, 'budget': None, 'genres': ['282', 'days/40', 'weeks'], 'title': 'Guess Who'}
# scraping  Sahara
# {'domestic': 68671925, 'international': 50568426, 'worldwide': 119240351, 'budget': 130000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Thriller'], 'title': 'Sahara'}
# scraping  Coach Carter
# {'domestic': 67264877, 'international': 9404677, 'worldwide': 76669554, 'budget': 30000000, 'genres': ['Biography', 'Drama', 'Sport'], 'title': 'Coach Carter'}
# scraping  Herbie Fully Loaded
# {'domestic': 66023816, 'international': 78123000, 'worldwide': 144146816, 'budget': 50000000, 'genres': ['193', 'days/27', 'weeks'], 'title': 'Herbie Fully Loaded'}
# scraping  The Amityville Horror
# {'domestic': 65233369, 'international': 42283000, 'worldwide': 107516369, 'budget': 19000000, 'genres': ['Horror'], 'title': 'The Amityville Horror'}
# scraping  Sky High
# {'domestic': 63946815, 'international': 22423000, 'worldwide': 86369815, 'budget': 35000000, 'genres': ['Adventure', 'Comedy', 'Family', 'Sci-Fi'], 'title': 'Sky High'}
# scraping  Bewitched
# {'domestic': 63313159, 'international': 68113010, 'worldwide': 131426169, 'budget': 85000000, 'genres': ['Comedy', 'Fantasy', 'Romance'], 'title': 'Bewitched'}
# scraping  Jarhead
# {'domestic': 62658220, 'international': 34417932, 'worldwide': 97076152, 'budget': 72000000, 'genres': ['Action', 'Biography', 'Drama', 'War'], 'title': 'Jarhead'}
# scraping  Cinderella Man
# {'domestic': 61649911, 'international': 46890000, 'worldwide': 108539911, 'budget': 88000000, 'genres': ['Biography', 'Drama', 'History', 'Romance', 'Sport'], 'title': 'Cinderella Man'}
# scraping  Red Eye
# {'domestic': 57891803, 'international': 38366398, 'worldwide': 96258201, 'budget': 26000000, 'genres': ['Thriller'], 'title': 'Red Eye'}
# scraping  White Noise
# {'domestic': 56386759, 'international': 34809660, 'worldwide': 91196419, 'budget': None, 'genres': ['359', 'days/51', 'weeks'], 'title': 'White Noise'}
# scraping  Be Cool
# {'domestic': 56046979, 'international': 39716737, 'worldwide': 95763716, 'budget': 53000000, 'genres': ['Comedy', 'Crime', 'Drama', 'Music', 'Romance'], 'title': 'Be Cool'}
# scraping  Wallace & Gromit: The Curse of the Were-Rabbit
# {'domestic': 56110897, 'international': 138000274, 'worldwide': 194111171, 'budget': 30000000, 'genres': ['453', 'days/64', 'weeks'], 'title': 'Wallace & Gromit: The Curse of the Were-Rabbit'}
# scraping  Fun with Dick and Jane
# {'domestic': 110332737, 'international': 94349162, 'worldwide': 204681899, 'budget': 100000000, 'genres': ['Comedy', 'Crime'], 'title': 'Fun with Dick and Jane'}
# scraping  Crash
# {'domestic': 54580300, 'international': 43829761, 'worldwide': 98410061, 'budget': 6500000, 'genres': ['Crime', 'Drama', 'Thriller'], 'title': 'Crash'}
# scraping  Corpse Bride
# {'domestic': 53359111, 'international': 64731725, 'worldwide': 118090836, 'budget': None, 'genres': ['112', 'days/16', 'weeks'], 'title': 'Corpse Bride'}
# scraping  Kicking & Screaming
# {'domestic': 52842724, 'international': 3227709, 'worldwide': 56070433, 'budget': 45000000, 'genres': ['Comedy', 'Family', 'Romance', 'Sport'], 'title': 'Kicking & Screaming'}
# scraping  Hide and Seek
# {'domestic': 51100486, 'international': 72104434, 'worldwide': 123204920, 'budget': None, 'genres': ['338', 'days/48', 'weeks'], 'title': 'Hide and Seek'}
# scraping  The Hitchhiker's Guide to the Galaxy
# {'domestic': 51085416, 'international': 53393000, 'worldwide': 104478416, 'budget': 50000000, 'genres': ['Adventure', 'Comedy', 'Sci-Fi'], 'title': "The Hitchhiker's Guide to the Galaxy"}
# scraping  Sideways
# {'domestic': 71503593, 'international': 38203338, 'worldwide': 109706931, 'budget': 16000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Sideways'}
# scraping  Diary of a Mad Black Woman
# {'domestic': 50633099, 'international': 19104, 'worldwide': 50652203, 'budget': 5500000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Diary of a Mad Black Woman'}
# scraping  Yours, Mine & Ours
# {'domestic': 53412862, 'international': 19250061, 'worldwide': 72662923, 'budget': 45000000, 'genres': ['Comedy', 'Family', 'Fantasy', 'Romance'], 'title': 'Yours, Mine & Ours'}
# scraping  Racing Stripes
# {'domestic': 49772522, 'international': 40981953, 'worldwide': 90754475, 'budget': None, 'genres': ['352', 'days/50', 'weeks'], 'title': 'Racing Stripes'}
# scraping  Miss Congeniality 2: Armed & Fabulous
# {'domestic': 48478006, 'international': 52915563, 'worldwide': 101393569, 'budget': None, 'genres': ['283', 'days/40', 'weeks'], 'title': 'Miss Congeniality 2: Armed & Fabulous'}
# scraping  Just Like Heaven
# {'domestic': 48318130, 'international': 54536301, 'worldwide': 102854431, 'budget': 58000000, 'genres': ['Comedy', 'Drama', 'Fantasy', 'Romance'], 'title': 'Just Like Heaven'}
# scraping  The Skeleton Key
# {'domestic': 47907715, 'international': 46076196, 'worldwide': 93983911, 'budget': 43000000, 'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'], 'title': 'The Skeleton Key'}
# scraping  Kingdom of Heaven
# {'domestic': 47398413, 'international': 170724214, 'worldwide': 218122627, 'budget': 130000000, 'genres': ['Action', 'Adventure', 'Drama', 'History', 'War'], 'title': 'Kingdom of Heaven'}
# scraping  Boogeyman
# {'domestic': 46752382, 'international': 20440477, 'worldwide': 67192859, 'budget': 20000000, 'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'], 'title': 'Boogeyman'}
# scraping  Cheaper by the Dozen 2
# {'domestic': 82571173, 'international': 47583395, 'worldwide': 130154568, 'budget': None, 'genres': ['376', 'days/53', 'weeks'], 'title': 'Cheaper by the Dozen 2'}
# scraping  In Good Company
# {'domestic': 45806659, 'international': 15508556, 'worldwide': 61315215, 'budget': None, 'genres': ['368', 'days/52', 'weeks'], 'title': 'In Good Company'}
# scraping  The Legend of Zorro
# {'domestic': 46464023, 'international': 95936042, 'worldwide': 142400065, 'budget': 75000000, 'genres': ['Action', 'Adventure', 'Romance', 'Thriller', 'Western'], 'title': 'The Legend of Zorro'}
# scraping  Must Love Dogs
# {'domestic': 43894863, 'international': 14336657, 'worldwide': 58231520, 'budget': 30000000, 'genres': ['Comedy', 'Romance'], 'title': 'Must Love Dogs'}
# scraping  Transporter 2
# {'domestic': 43095856, 'international': 45987373, 'worldwide': 89083229, 'budget': 32000000, 'genres': ['Action', 'Thriller'], 'title': 'Transporter 2'}
# scraping  Fever Pitch
# {'domestic': 42071069, 'international': 8534094, 'worldwide': 50605163, 'budget': 30000000, 'genres': ['Comedy', 'Drama', 'Romance', 'Sport'], 'title': 'Fever Pitch'}
# scraping  The Family Stone
# {'domestic': 60062868, 'international': 32821561, 'worldwide': 92884429, 'budget': 18000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'The Family Stone'}
# scraping  The Adventures of Sharkboy and Lavagirl 3-D
# {'domestic': 39177684, 'international': 32814971, 'worldwide': 71992655, 'budget': None, 'genres': ['205', 'days/29', 'weeks'], 'title': 'The Adventures of Sharkboy and Lavagirl 3-D'}
# scraping  The Sisterhood of the Traveling Pants
# {'domestic': 39053061, 'international': 2960817, 'worldwide': 42013878, 'budget': 25000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'The Sisterhood of the Traveling Pants'}
# scraping  The Phantom of the Opera
# {'domestic': 51268815, 'international': 103380072, 'worldwide': 154648887, 'budget': 70000000, 'genres': ['Drama', 'Musical', 'Romance', 'Thriller'], 'title': 'The Phantom of the Opera'}
# scraping  The Brothers Grimm
# {'domestic': 37916267, 'international': 67400000, 'worldwide': 105316267, 'budget': 88000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Horror', 'Mystery', 'Thriller'], 'title': 'The Brothers Grimm'}
# scraping  Beauty Shop
# {'domestic': 36351350, 'international': 894103, 'worldwide': 37245453, 'budget': None, 'genres': ['277', 'days/39', 'weeks'], 'title': 'Beauty Shop'}
# scraping  Syriana
# {'domestic': 50824620, 'international': 43150000, 'worldwide': 93974620, 'budget': 50000000, 'genres': ['Drama', 'Thriller'], 'title': 'Syriana'}
# scraping  The Island
# {'domestic': 35818913, 'international': 127130251, 'worldwide': 162949164, 'budget': 126000000, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The Island'}
# scraping  Derailed
# {'domestic': 36024076, 'international': 21455000, 'worldwide': 57479076, 'budget': 22000000, 'genres': ['Crime', 'Drama', 'Thriller'], 'title': 'Derailed'}
# scraping  Hostage
# {'domestic': 34639939, 'international': 42968678, 'worldwide': 77608617, 'budget': None, 'genres': ['296', 'days/42', 'weeks'], 'title': 'Hostage'}
# scraping  Lemony Snicket's A Series of Unfortunate Events
# {'domestic': 118634549, 'international': 92833686, 'worldwide': 211468235, 'budget': 140000000, 'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'], 'title': "Lemony Snicket's A Series of Unfortunate Events"}
# scraping  The Constant Gardener
# {'domestic': 33579797, 'international': 48886873, 'worldwide': 82466670, 'budget': 25000000, 'genres': ['Drama', 'Mystery', 'Romance', 'Thriller'], 'title': 'The Constant Gardener'}
# scraping  Pride & Prejudice
# {'domestic': 38405088, 'international': 83211467, 'worldwide': 121616555, 'budget': None, 'genres': ['416', 'days/59', 'weeks'], 'title': 'Pride & Prejudice'}
# scraping  Bad News Bears
# {'domestic': 32868349, 'international': 1384498, 'worldwide': 34252847, 'budget': 35000000, 'genres': ['Comedy', 'Sport'], 'title': 'Bad News Bears'}
# scraping  In Her Shoes
# {'domestic': 32880591, 'international': 50816882, 'worldwide': 83697473, 'budget': None, 'genres': ['451', 'days/64', 'weeks'], 'title': 'In Her Shoes'}
# scraping  Because of Winn-Dixie
# {'domestic': 32647042, 'international': 942385, 'worldwide': 33589427, 'budget': 14000000, 'genres': ['Comedy', 'Drama', 'Family'], 'title': 'Because of Winn-Dixie'}
# scraping  Dreamer: Inspired by a True Story
# {'domestic': 32751093, 'international': 5990639, 'worldwide': 38741732, 'budget': 32000000, 'genres': ['Drama', 'Family', 'Sport'], 'title': 'Dreamer: Inspired by a True Story'}
# scraping  Stealth
# {'domestic': 32116746, 'international': 47151576, 'worldwide': 79268322, 'budget': 135000000, 'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'title': 'Stealth'}
# scraping  House of Wax
# {'domestic': 32064800, 'international': 36701321, 'worldwide': 68766121, 'budget': 40000000, 'genres': ['Horror', 'Thriller'], 'title': 'House of Wax'}
# scraping  The Wedding Date
# {'domestic': 31726995, 'international': 15369211, 'worldwide': 47096206, 'budget': 15000000, 'genres': ['Comedy', 'Romance'], 'title': 'The Wedding Date'}
# scraping  Just Friends
# {'domestic': 32619671, 'international': 18292763, 'worldwide': 50912434, 'budget': None, 'genres': ['404', 'days/57', 'weeks'], 'title': 'Just Friends'}
# scraping  A History of Violence
# {'domestic': 31504633, 'international': 29880432, 'worldwide': 61385065, 'budget': 32000000, 'genres': ['Drama', 'Thriller'], 'title': 'A History of Violence'}
# scraping  Get Rich or Die Tryin'
# {'domestic': 30985352, 'international': 15578609, 'worldwide': 46563961, 'budget': 40000000, 'genres': ['Biography', 'Crime', 'Drama', 'Music'], 'title': "Get Rich or Die Tryin'"}
# scraping  The Fog
# {'domestic': 29550869, 'international': 16650563, 'worldwide': 46201432, 'budget': 18000000, 'genres': ['Horror', 'Mystery'], 'title': 'The Fog'}
# scraping  Rent
# {'domestic': 29077547, 'international': 2593073, 'worldwide': 31670620, 'budget': 40000000, 'genres': ['Drama', 'Musical', 'Romance'], 'title': 'Rent'}
# scraping  Doom
# {'domestic': 28212337, 'international': 29859782, 'worldwide': 58072119, 'budget': 60000000, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Doom'}
# scraping  Zathura: A Space Adventure
# {'domestic': 29258869, 'international': 35820235, 'worldwide': 65079104, 'budget': 65000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi'], 'title': 'Zathura: A Space Adventure'}
# scraping  Finding Neverland
# {'domestic': 51680613, 'international': 64970000, 'worldwide': 116650613, 'budget': 25000000, 'genres': ['Biography', 'Drama', 'Family'], 'title': 'Finding Neverland'}
# scraping  xXx: State of the Union
# {'domestic': 26873932, 'international': 44148761, 'worldwide': 71022693, 'budget': None, 'genres': ['247', 'days/35', 'weeks'], 'title': 'xXx: State of the Union'}
# scraping  Elizabethtown
# {'domestic': 26850426, 'international': 25313590, 'worldwide': 52164016, 'budget': 45000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Elizabethtown'}
# scraping  Serenity
# {'domestic': 25514517, 'international': 14930612, 'worldwide': 40445129, 'budget': 39000000, 'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'title': 'Serenity'}
# scraping  Dark Water
# {'domestic': 25473352, 'international': 18873727, 'worldwide': 44347079, 'budget': None, 'genres': ['177', 'days/25', 'weeks'], 'title': 'Dark Water'}
# scraping  Memoirs of a Geisha
# {'domestic': 57490508, 'international': 104752454, 'worldwide': 162242962, 'budget': 85000000, 'genres': ['Drama', 'Romance'], 'title': 'Memoirs of a Geisha'}
# scraping  Ocean's Twelve
# {'domestic': 125544280, 'international': 237200000, 'worldwide': 362744280, 'budget': 110000000, 'genres': ['Crime', 'Thriller'], 'title': "Ocean's Twelve"}
# scraping  Æon Flux
# {'domestic': 25874337, 'international': 27447336, 'worldwide': 53321673, 'budget': 62000000, 'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'title': 'Æon Flux'}
# scraping  Rumor Has It...
# {'domestic': 43000262, 'international': 45933300, 'worldwide': 88933562, 'budget': None, 'genres': ['372', 'days/53', 'weeks'], 'title': 'Rumor Has It...'}
# scraping  Unleashed
# {'domestic': 24537621, 'international': 26333492, 'worldwide': 50871113, 'budget': 45000000, 'genres': ['Action', 'Adventure', 'Crime', 'Drama', 'Thriller'], 'title': 'Unleashed'}
# scraping  Elektra
# {'domestic': 24409722, 'international': 32585924, 'worldwide': 56995646, 'budget': 43000000, 'genres': ['Action', 'Adventure', 'Crime', 'Fantasy'], 'title': 'Elektra'}
# scraping  Ice Princess
# {'domestic': 24402491, 'international': 3243000, 'worldwide': 27645491, 'budget': None, 'genres': ['289', 'days/41', 'weeks'], 'title': 'Ice Princess'}
# scraping  Lord of War
# {'domestic': 24149632, 'international': 48467436, 'worldwide': 72617068, 'budget': 50000000, 'genres': ['Action', 'Crime', 'Drama'], 'title': 'Lord of War'}
# scraping  Good Night, and Good Luck.
# {'domestic': 31558003, 'international': 23083188, 'worldwide': 54641191, 'budget': 7000000, 'genres': ['Biography', 'Drama', 'History'], 'title': 'Good Night, and Good Luck.'}
# scraping  Hotel Rwanda
# {'domestic': 23530892, 'international': 10351351, 'worldwide': 33882243, 'budget': None, 'genres': ['375', 'days/53', 'weeks'], 'title': 'Hotel Rwanda'}
# scraping  Two for the Money
# {'domestic': 22991379, 'international': 7535130, 'worldwide': 30526509, 'budget': 35000000, 'genres': ['Crime', 'Drama', 'Sport'], 'title': 'Two for the Money'}
# scraping  National Treasure
# {'domestic': 173008894, 'international': 174503424, 'worldwide': 347512318, 'budget': 100000000, 'genres': ['Action', 'Adventure', 'Mystery', 'Thriller'], 'title': 'National Treasure'}
# scraping  Prime
# {'domestic': 22827153, 'international': 45110341, 'worldwide': 67937494, 'budget': 22000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Prime'}
# scraping  Deuce Bigalow: European Gigolo
# {'domestic': 22400154, 'international': 22709407, 'worldwide': 45109561, 'budget': 22000000, 'genres': ['Comedy'], 'title': 'Deuce Bigalow: European Gigolo'}
# scraping  Hustle & Flow
# {'domestic': 22202809, 'international': 1360918, 'worldwide': 23563727, 'budget': 2800000, 'genres': ['Crime', 'Drama', 'Music'], 'title': 'Hustle & Flow'}
# scraping  Fat Albert
# {'domestic': 48116322, 'international': 435000, 'worldwide': 48551322, 'budget': None, 'genres': ['372', 'days/53', 'weeks'], 'title': 'Fat Albert'}
# scraping  A Lot Like Love
# {'domestic': 21845719, 'international': 21041000, 'worldwide': 42886719, 'budget': 30000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'A Lot Like Love'}
# scraping  Land of the Dead
# {'domestic': 20700082, 'international': 26374051, 'worldwide': 47074133, 'budget': 15000000, 'genres': ['Horror', 'Sci-Fi', 'Thriller'], 'title': 'Land of the Dead'}
# scraping  Assault on Precinct 13
# {'domestic': 20040895, 'international': 15253575, 'worldwide': 35294470, 'budget': 30000000, 'genres': ['Action', 'Crime', 'Drama', 'Thriller'], 'title': 'Assault on Precinct 13'}
# scraping  Man of the House
# {'domestic': 19699706, 'international': 1877918, 'worldwide': 21577624, 'budget': None, 'genres': ['310', 'days/44', 'weeks'], 'title': 'Man of the House'}
# scraping  Valiant
# {'domestic': 19478106, 'international': 42268782, 'worldwide': 61746888, 'budget': 35000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'War'], 'title': 'Valiant'}
# scraping  Cursed
# {'domestic': 19297522, 'international': 10324200, 'worldwide': 29621722, 'budget': 38000000, 'genres': ['Comedy', 'Horror'], 'title': 'Cursed'}
# scraping  The Upside of Anger
# {'domestic': 18761993, 'international': 9475495, 'worldwide': 28237488, 'budget': 12000000, 'genres': ['Comedy', 'Drama'], 'title': 'The Upside of Anger'}
# scraping  Into the Blue
# {'domestic': 18801234, 'international': 27316462, 'worldwide': 46117696, 'budget': None, 'genres': ['458', 'days/65', 'weeks'], 'title': 'Into the Blue'}
# scraping  North Country
# {'domestic': 18337722, 'international': 6873453, 'worldwide': 25211175, 'budget': 35000000, 'genres': ['Drama'], 'title': 'North Country'}
# scraping  Pooh's Heffalump Movie
# {'domestic': 18098433, 'international': 34760000, 'worldwide': 52858433, 'budget': 20000000, 'genres': ['Animation', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Mystery'], 'title': "Pooh's Heffalump Movie"}
# scraping  Roll Bounce
# {'domestic': 17380866, 'international': 120000, 'worldwide': 17500866, 'budget': None, 'genres': ['465', 'days/66', 'weeks'], 'title': 'Roll Bounce'}
# scraping  The Ringer
# {'domestic': 35428675, 'international': 5013768, 'worldwide': 40442443, 'budget': None, 'genres': ['374', 'days/53', 'weeks'], 'title': 'The Ringer'}
# scraping  Kung Fu Hustle
# {'domestic': 17108591, 'international': 83803854, 'worldwide': 100912445, 'budget': 20000000, 'genres': ['Action', 'Comedy', 'Fantasy'], 'title': 'Kung Fu Hustle'}
# scraping  The Devil's Rejects
# {'domestic': 17044981, 'international': 3856878, 'worldwide': 20901859, 'budget': 7000000, 'genres': ['Horror'], 'title': "The Devil's Rejects"}
# scraping  Son of the Mask
# {'domestic': 17018422, 'international': 42963126, 'worldwide': 59981548, 'budget': 84000000, 'genres': ['Comedy', 'Family', 'Fantasy'], 'title': 'Son of the Mask'}
# scraping  Rebound
# {'domestic': 16809014, 'international': 683000, 'worldwide': 17492014, 'budget': 33100000, 'genres': ['Comedy', 'Family', 'Sport'], 'title': 'Rebound'}
# scraping  The Perfect Man
# {'domestic': 16535005, 'international': 3235470, 'worldwide': 19770475, 'budget': 10000000, 'genres': ['Comedy', 'Family', 'Romance'], 'title': 'The Perfect Man'}
# scraping  Spanglish
# {'domestic': 42726869, 'international': 12743285, 'worldwide': 55470154, 'budget': 80000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Spanglish'}
# scraping  Waiting...
# {'domestic': 16124543, 'international': 2513147, 'worldwide': 18637690, 'budget': 3000000, 'genres': ['Comedy'], 'title': 'Waiting...'}
# scraping  The Gospel
# {'domestic': 15778152, 'international': None, 'worldwide': 15778152, 'budget': 4000000, 'genres': ['Drama', 'Music'], 'title': 'The Gospel'}
# scraping  The Greatest Game Ever Played
# {'domestic': 15337393, 'international': 93784, 'worldwide': 15431177, 'budget': None, 'genres': ['98', 'days/14', 'weeks'], 'title': 'The Greatest Game Ever Played'}
# scraping  The Cave
# {'domestic': 15007991, 'international': 18288466, 'worldwide': 33296457, 'budget': None, 'genres': ['128', 'days/18', 'weeks'], 'title': 'The Cave'}
# scraping  Broken Flowers
# {'domestic': 13744960, 'international': 33585001, 'worldwide': 47329961, 'budget': None, 'genres': ['154', 'days/22', 'weeks'], 'title': 'Broken Flowers'}
# scraping  The Honeymooners
# {'domestic': 12843849, 'international': 339577, 'worldwide': 13183426, 'budget': 25000000, 'genres': ['Comedy', 'Family', 'Romance'], 'title': 'The Honeymooners'}
# scraping  The Life Aquatic with Steve Zissou
# {'domestic': 24020403, 'international': 10788000, 'worldwide': 34808403, 'budget': 50000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Drama', 'Romance'], 'title': 'The Life Aquatic with Steve Zissou'}
# scraping  The Incredibles
# {'domestic': 261441092, 'international': 370001000, 'worldwide': 631442092, 'budget': 92000000, 'genres': ['422', 'days/60', 'weeks'], 'title': 'The Incredibles'}
# scraping  The Weather Man
# {'domestic': 12482775, 'international': 6643623, 'worldwide': 19126398, 'budget': 22000000, 'genres': ['Comedy', 'Drama'], 'title': 'The Weather Man'}
# scraping  Brokeback Mountain
# {'domestic': 83043761, 'international': 95018998, 'worldwide': 178062759, 'budget': 14000000, 'genres': ['Drama', 'Romance'], 'title': 'Brokeback Mountain'}
# scraping  Munich
# {'domestic': 47403685, 'international': 83578444, 'worldwide': 130982129, 'budget': 70000000, 'genres': ['Action', 'Drama', 'History', 'Thriller'], 'title': 'Munich'}
# scraping  Capote
# {'domestic': 28750530, 'international': 20576875, 'worldwide': 49327405, 'budget': 7000000, 'genres': ['Biography', 'Crime', 'Drama', 'History'], 'title': 'Capote'}
# scraping  Lords of Dogtown
# {'domestic': 11273517, 'international': 2138440, 'worldwide': 13411957, 'budget': 25000000, 'genres': ['Biography', 'Drama', 'Sport'], 'title': 'Lords of Dogtown'}
# scraping  The Polar Express
# {'domestic': 162775358, 'international': 123225147, 'worldwide': 286000505, 'budget': 165000000, 'genres': ['417', 'days/59', 'weeks'], 'title': 'The Polar Express'}
# scraping  Wolf Creek
# {'domestic': 16188180, 'international': 14574468, 'worldwide': 30762648, 'budget': None, 'genres': ['372', 'days/53', 'weeks'], 'title': 'Wolf Creek'}
# scraping  In the Mix
# {'domestic': 10223896, 'international': None, 'worldwide': 10223896, 'budget': None, 'genres': ['44', 'days/6', 'weeks'], 'title': 'In the Mix'}
# scraping  Domino
# {'domestic': 10169202, 'international': 12775300, 'worldwide': 22944502, 'budget': None, 'genres': ['84', 'days/12', 'weeks'], 'title': 'Domino'}
# scraping  The Great Raid
# {'domestic': 10167373, 'international': 601938, 'worldwide': 10769311, 'budget': 80000000, 'genres': ['Action', 'Drama', 'War'], 'title': 'The Great Raid'}
# scraping  Shopgirl
# {'domestic': 10284523, 'international': 1390638, 'worldwide': 11675161, 'budget': None, 'genres': ['437', 'days/62', 'weeks'], 'title': 'Shopgirl'}
# scraping  Cry Wolf
# {'domestic': 10047674, 'international': 22538734, 'worldwide': 32586408, 'budget': 1000000, 'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'], 'title': 'Cry Wolf'}
# scraping  The Polar Express
# {'domestic': 10900597, 'international': 1009883, 'worldwide': 11910480, 'budget': 165000000, 'genres': ['404', 'days/57', 'weeks'], 'title': 'The Polar Express'}
# scraping  Darkness
# {'domestic': 22163442, 'international': 11825294, 'worldwide': 33988736, 'budget': 10600000, 'genres': ['Horror'], 'title': 'Darkness'}
# scraping  The Producers
# {'domestic': 19398532, 'international': 18676786, 'worldwide': 38075318, 'budget': 45000000, 'genres': ['Comedy', 'Crime', 'Musical'], 'title': 'The Producers'}
# scraping  The Ice Harvest
# {'domestic': 9016782, 'international': 1140186, 'worldwide': 10156968, 'budget': None, 'genres': ['44', 'days/6', 'weeks'], 'title': 'The Ice Harvest'}
# scraping  An Unfinished Life
# {'domestic': 8586392, 'international': 10031892, 'worldwide': 18618284, 'budget': 30000000, 'genres': ['Drama', 'Family', 'Romance'], 'title': 'An Unfinished Life'}
# scraping  The Man
# {'domestic': 8330720, 'international': 5154425, 'worldwide': 13485145, 'budget': None, 'genres': ['114', 'days/16', 'weeks'], 'title': 'The Man'}
# scraping  Closer
# {'domestic': 33987757, 'international': 81517270, 'worldwide': 115505027, 'budget': 27000000, 'genres': ['Drama', 'Romance'], 'title': 'Closer'}
# scraping  Mad Hot Ballroom
# {'domestic': 8117961, 'international': 961081, 'worldwide': 9079042, 'budget': None, 'genres': ['238', 'days/34', 'weeks'], 'title': 'Mad Hot Ballroom'}
# scraping  Aliens of the Deep
# {'domestic': 8968684, 'international': 3801953, 'worldwide': 12770637, 'budget': None, 'genres': ['1,071', 'days/153', 'weeks'], 'title': 'Aliens of the Deep'}
# scraping  Proof
# {'domestic': 7535331, 'international': 6654529, 'worldwide': 14189860, 'budget': 20000000, 'genres': ['Drama', 'Mystery'], 'title': 'Proof'}
# scraping  House of Flying Daggers
# {'domestic': 11050094, 'international': 81813851, 'worldwide': 92863945, 'budget': None, 'genres': ['394', 'days/56', 'weeks'], 'title': 'House of Flying Daggers'}
# scraping  Space Station 3D
# {'domestic': 93383953, 'international': 34979928, 'worldwide': 128363881, 'budget': None, 'genres': ['64', 'theaters'], 'title': 'Space Station 3D'}
# scraping  Ladies in Lavender
# {'domestic': 6765081, 'international': 13611994, 'worldwide': 20377075, 'budget': None, 'genres': ['247', 'days/35', 'weeks'], 'title': 'Ladies in Lavender'}
# scraping  Bride & Prejudice
# {'domestic': 6605592, 'international': 18110848, 'worldwide': 24716440, 'budget': 7000000, 'genres': ['Comedy', 'Drama', 'Musical', 'Romance'], 'title': 'Bride & Prejudice'}
# scraping  Millions
# {'domestic': 6584159, 'international': 5198123, 'worldwide': 11782282, 'budget': None, 'genres': ['296', 'days/42', 'weeks'], 'title': 'Millions'}
# scraping  Flight of the Phoenix
# {'domestic': 21009180, 'international': 14012317, 'worldwide': 35021497, 'budget': 45000000, 'genres': ['Action', 'Adventure', 'Drama', 'Romance', 'Thriller'], 'title': 'Flight of the Phoenix'}
# scraping  The Aristocrats
# {'domestic': 6377461, 'international': 431628, 'worldwide': 6809089, 'budget': None, 'genres': ['234', 'theaters'], 'title': 'The Aristocrats'}
# scraping  The Jacket
# {'domestic': 6303762, 'international': 14822463, 'worldwide': 21126225, 'budget': None, 'genres': ['303', 'days/43', 'weeks'], 'title': 'The Jacket'}
# scraping  Magnificent Desolation: Walking on the Moon 3D
# {'domestic': 34137524, 'international': 6201878, 'worldwide': 40339402, 'budget': None, 'genres': ['82', 'theaters'], 'title': 'Magnificent Desolation: Walking on the Moon 3D'}
# scraping  Underclassman
# {'domestic': 5655459, 'international': 224096, 'worldwide': 5879555, 'budget': None, 'genres': ['121', 'days/17', 'weeks'], 'title': 'Underclassman'}
# scraping  Blade: Trinity
# {'domestic': 52411906, 'international': 79565998, 'worldwide': 131977904, 'budget': 65000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Horror', 'Sci-Fi'], 'title': 'Blade: Trinity'}
# scraping  Downfall
# {'domestic': 5509040, 'international': 86672534, 'worldwide': 92181574, 'budget': None, 'genres': ['317', 'days/45', 'weeks'], 'title': 'Downfall'}
# scraping  Beyond the Sea
# {'domestic': 6318709, 'international': 2128906, 'worldwide': 8447615, 'budget': None, 'genres': ['380', 'days/54', 'weeks'], 'title': 'Beyond the Sea'}
# scraping  Alone in the Dark
# {'domestic': 5178569, 'international': 5264239, 'worldwide': 10442808, 'budget': 20000000, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Alone in the Dark'}
# scraping  The Squid and the Whale
# {'domestic': 7372734, 'international': 3725397, 'worldwide': 11098131, 'budget': 1500000, 'genres': ['Comedy', 'Drama'], 'title': 'The Squid and the Whale'}
# scraping  Wild Safari - A South African Adventure
# {'domestic': 16621530, 'international': 17635605, 'worldwide': 34257135, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Wild Safari - A South African Adventure'}
# scraping  Howl's Moving Castle
# {'domestic': 4711096, 'international': 230636249, 'worldwide': 235347345, 'budget': None, 'genres': ['205', 'days/29', 'weeks'], 'title': "Howl's Moving Castle"}
# scraping  Ong-Bak: The Thai Warrior
# {'domestic': 4563167, 'international': 15672259, 'worldwide': 20235426, 'budget': None, 'genres': ['324', 'days/46', 'weeks'], 'title': 'Ong-Bak: The Thai Warrior'}
# scraping  Mindhunters
# {'domestic': 4480744, 'international': 16668085, 'worldwide': 21148829, 'budget': None, 'genres': ['233', 'days/33', 'weeks'], 'title': 'Mindhunters'}
# scraping  A Very Long Engagement
# {'domestic': 6524389, 'international': 62900000, 'worldwide': 69424389, 'budget': 56600000, 'genres': ['Drama', 'Mystery', 'Romance', 'War'], 'title': 'A Very Long Engagement'}
# scraping  The SpongeBob SquarePants Movie
# {'domestic': 85417988, 'international': 54775005, 'worldwide': 140192993, 'budget': 30000000, 'genres': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'], 'title': 'The SpongeBob SquarePants Movie'}
# scraping  Being Julia
# {'domestic': 7739049, 'international': 6600122, 'worldwide': 14339171, 'budget': None, 'genres': ['443', 'days/63', 'weeks'], 'title': 'Being Julia'}
# scraping  Kiss Kiss Bang Bang
# {'domestic': 4243756, 'international': 11541392, 'worldwide': 15785148, 'budget': 15000000, 'genres': ['Action', 'Comedy', 'Crime', 'Mystery', 'Thriller'], 'title': 'Kiss Kiss Bang Bang'}
# scraping  Enron: The Smartest Guys in the Room
# {'domestic': 4071700, 'international': 782464, 'worldwide': 4854164, 'budget': None, 'genres': ['151', 'theaters'], 'title': 'Enron: The Smartest Guys in the Room'}
# scraping  Ray
# {'domestic': 75331600, 'international': 48639776, 'worldwide': 123971376, 'budget': 40000000, 'genres': ['Biography', 'Drama', 'Music'], 'title': 'Ray'}
# scraping  King's Ransom
# {'domestic': 4008527, 'international': 135125, 'worldwide': 4143652, 'budget': None, 'genres': ['254', 'days/36', 'weeks'], 'title': "King's Ransom"}
# scraping  Kinsey
# {'domestic': 10254979, 'international': 6795038, 'worldwide': 17050017, 'budget': 11000000, 'genres': ['Biography', 'Drama', 'Romance'], 'title': 'Kinsey'}
# scraping  Me and You and Everyone We Know
# {'domestic': 3885134, 'international': 4127704, 'worldwide': 8012838, 'budget': None, 'genres': ['198', 'days/28', 'weeks'], 'title': 'Me and You and Everyone We Know'}
# scraping  Melinda and Melinda
# {'domestic': 3826280, 'international': 16303047, 'worldwide': 20129327, 'budget': None, 'genres': ['289', 'days/41', 'weeks'], 'title': 'Melinda and Melinda'}
# scraping  The Merchant of Venice
# {'domestic': 3765585, 'international': 17652140, 'worldwide': 21417725, 'budget': 30000000, 'genres': ['Drama', 'Romance'], 'title': 'The Merchant of Venice'}
# scraping  High Tension
# {'domestic': 3681066, 'international': 2610892, 'worldwide': 6291958, 'budget': None, 'genres': ['205', 'days/29', 'weeks'], 'title': 'High Tension'}
# scraping  Bad Education
# {'domestic': 5211842, 'international': 35138995, 'worldwide': 40350837, 'budget': 5000000, 'genres': ['Crime', 'Drama'], 'title': 'Bad Education'}
# scraping  Stay
# {'domestic': 3626883, 'international': 4856914, 'worldwide': 8483797, 'budget': None, 'genres': ['77', 'days/11', 'weeks'], 'title': 'Stay'}
# scraping  Born Into Brothels: Calcutta's Red Light Kids
# {'domestic': 3515061, 'international': 14140, 'worldwide': 3529201, 'budget': None, 'genres': ['389', 'days/55', 'weeks'], 'title': "Born Into Brothels: Calcutta's Red Light Kids"}
# scraping  Rize
# {'domestic': 3336391, 'international': 1310498, 'worldwide': 4646889, 'budget': None, 'genres': ['191', 'days/27', 'weeks'], 'title': 'Rize'}
# scraping  Grizzly Man
# {'domestic': 3178403, 'international': 882902, 'worldwide': 4061305, 'budget': None, 'genres': ['147', 'days/21', 'weeks'], 'title': 'Grizzly Man'}
# scraping  Supercross
# {'domestic': 3102550, 'international': 241881, 'worldwide': 3344431, 'budget': None, 'genres': ['137', 'days/19', 'weeks'], 'title': 'Supercross'}
# scraping  The Wild Parrots of Telegraph Hill
# {'domestic': 3058527, 'international': 160182, 'worldwide': 3218709, 'budget': None, 'genres': ['691', 'days/98', 'weeks'], 'title': 'The Wild Parrots of Telegraph Hill'}
# scraping  G
# {'domestic': 3020784, 'international': None, 'worldwide': 3020784, 'budget': None, 'genres': ['112', 'days/16', 'weeks'], 'title': 'G'}
# scraping  Bugs!
# {'domestic': 19063544, 'international': 10325455, 'worldwide': 29388999, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Bugs!'}
# scraping  Walk on Water
# {'domestic': 2713932, 'international': 1730333, 'worldwide': 4444265, 'budget': None, 'genres': ['303', 'days/43', 'weeks'], 'title': 'Walk on Water'}
# scraping  Junebug
# {'domestic': 2678691, 'international': 720537, 'worldwide': 3399228, 'budget': None, 'genres': ['156', 'days/22', 'weeks'], 'title': 'Junebug'}
# scraping  T-Rex: Back to the Cretaceous
# {'domestic': 53354743, 'international': 50605624, 'worldwide': 103960367, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'T-Rex: Back to the Cretaceous'}
# scraping  Layer Cake
# {'domestic': 2339957, 'international': 9510257, 'worldwide': 11850214, 'budget': None, 'genres': ['233', 'days/33', 'weeks'], 'title': 'Layer Cake'}
# scraping  Haunted Castle
# {'domestic': 13651656, 'international': 25441510, 'worldwide': 39093166, 'budget': None, 'genres': ['10', 'theaters'], 'title': 'Haunted Castle'}
# scraping  The Work and the Glory
# {'domestic': 3347647, 'international': None, 'worldwide': 3347647, 'budget': 7500000, 'genres': ['Drama', 'Romance'], 'title': 'The Work and the Glory'}
# scraping  Pulse: A Stomp Odyssey
# {'domestic': 10086514, 'international': None, 'worldwide': 10086514, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Pulse: A Stomp Odyssey'}
# scraping  Oliver Twist
# {'domestic': 2080321, 'international': 40500000, 'worldwide': 42580321, 'budget': 60000000, 'genres': ['Crime', 'Drama'], 'title': 'Oliver Twist'}
# scraping  NASCAR: The IMAX Experience
# {'domestic': 21583831, 'international': 665000, 'worldwide': 22248831, 'budget': None, 'genres': ['665', 'days/95', 'weeks'], 'title': 'NASCAR: The IMAX Experience'}
# scraping  The Sea Inside
# {'domestic': 2104923, 'international': 41580526, 'worldwide': 43685449, 'budget': None, 'genres': ['380', 'days/54', 'weeks'], 'title': 'The Sea Inside'}
# scraping  Adrenaline Rush: The Science of Risk
# {'domestic': 10994028, 'international': 17904, 'worldwide': 11011932, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Adrenaline Rush: The Science of Risk'}
# scraping  The Work and the Glory II: American Zion
# {'domestic': 2025032, 'international': None, 'worldwide': 2025032, 'budget': 6500000, 'genres': ['Drama', 'Western'], 'title': 'The Work and the Glory II: American Zion'}
# scraping  A Sound of Thunder
# {'domestic': 1900451, 'international': 9765014, 'worldwide': 11665465, 'budget': 80000000, 'genres': ['Action', 'Adventure', 'Horror', 'Sci-Fi', 'Thriller'], 'title': 'A Sound of Thunder'}
# scraping  Look at Me
# {'domestic': 1737308, 'international': 16992443, 'worldwide': 18729751, 'budget': None, 'genres': ['275', 'days/39', 'weeks'], 'title': 'Look at Me'}
# scraping  Everything Is Illuminated
# {'domestic': 1712337, 'international': 1889637, 'worldwide': 3601974, 'budget': None, 'genres': ['112', 'days/16', 'weeks'], 'title': 'Everything Is Illuminated'}
# scraping  State Property: Blood on the Streets
# {'domestic': 1691706, 'international': None, 'worldwide': 1691706, 'budget': None, 'genres': ['263', 'days/37', 'weeks'], 'title': 'State Property: Blood on the Streets'}
# scraping  Christmas with the Kranks
# {'domestic': 73780539, 'international': 22791941, 'worldwide': 96572480, 'budget': 60000000, 'genres': ['Comedy', 'Family'], 'title': 'Christmas with the Kranks'}
# scraping  Vera Drake
# {'domestic': 3775283, 'international': 9492586, 'worldwide': 13267869, 'budget': None, 'genres': ['450', 'days/64', 'weeks'], 'title': 'Vera Drake'}
# scraping  Ma vie en cinémascope
# {'domestic': 2750263, 'international': None, 'worldwide': 2750263, 'budget': None, 'genres': [], 'title': 'Ma vie en cinémascope'}
# scraping  The Chorus
# {'domestic': 1548036, 'international': 4805774, 'worldwide': 6353810, 'budget': None, 'genres': ['352', 'days/50', 'weeks'], 'title': 'The Chorus'}
# scraping  Murderball
# {'domestic': 1531154, 'international': 219057, 'worldwide': 1750211, 'budget': None, 'genres': ['177', 'days/25', 'weeks'], 'title': 'Murderball'}
# scraping  2046
# {'domestic': 1444588, 'international': 18025651, 'worldwide': 19470239, 'budget': 12000000, 'genres': ['Drama', 'Romance', 'Sci-Fi'], 'title': '2046'}
# scraping  Hello Greetings
# {'domestic': 1413283, 'international': 7876656, 'worldwide': 9289939, 'budget': None, 'genres': ['63', 'theaters'], 'title': 'Hello Greetings'}
# scraping  Riddle
# {'domestic': 1409499, 'international': 1006476, 'worldwide': 2415975, 'budget': None, 'genres': ['68', 'theaters'], 'title': 'Riddle'}
# scraping  The Woodsman
# {'domestic': 1576231, 'international': 3102174, 'worldwide': 4678405, 'budget': None, 'genres': ['373', 'days/53', 'weeks'], 'title': 'The Woodsman'}
# scraping  Dear Frankie
# {'domestic': 18025, 'international': 1638804, 'worldwide': 1656829, 'budget': None, 'genres': ['308', 'days/44', 'weeks'], 'title': 'Dear Frankie'}
# scraping  Ushpizin
# {'domestic': 1400666, 'international': 164350, 'worldwide': 1565016, 'budget': None, 'genres': ['439', 'days/62', 'weeks'], 'title': 'Ushpizin'}
# scraping  Thumbsucker
# {'domestic': 1328679, 'international': 810063, 'worldwide': 2138742, 'budget': None, 'genres': ['112', 'days/16', 'weeks'], 'title': 'Thumbsucker'}
# scraping  Off the Map
# {'domestic': 1317167, 'international': 2325, 'worldwide': 1319492, 'budget': None, 'genres': ['296', 'days/42', 'weeks'], 'title': 'Off the Map'}
# scraping  Happy Endings
# {'domestic': 1315701, 'international': 357587, 'worldwide': 1673288, 'budget': None, 'genres': ['170', 'days/24', 'weeks'], 'title': 'Happy Endings'}
# scraping  El vacilón: The Movie
# {'domestic': 1291951, 'international': 398978, 'worldwide': 1690929, 'budget': None, 'genres': ['77', 'days/11', 'weeks'], 'title': 'El vacilón: The Movie'}
# scraping  The Motorcycle Diaries
# {'domestic': 16781387, 'international': 40881837, 'worldwide': 57663224, 'budget': None, 'genres': ['464', 'days/66', 'weeks'], 'title': 'The Motorcycle Diaries'}
# scraping  Saving Face
# {'domestic': 1187266, 'international': 49252, 'worldwide': 1236518, 'budget': None, 'genres': ['219', 'days/31', 'weeks'], 'title': 'Saving Face'}
# scraping  Heights
# {'domestic': 1160817, 'international': 145464, 'worldwide': 1306281, 'budget': None, 'genres': ['198', 'days/28', 'weeks'], 'title': 'Heights'}
# scraping  Bee Season
# {'domestic': 1180560, 'international': 5676429, 'worldwide': 6856989, 'budget': 14000000, 'genres': ['Drama', 'Family'], 'title': 'Bee Season'}
# scraping  Sarah Silverman: Jesus Is Magic
# {'domestic': 1324339, 'international': 9460, 'worldwide': 1333799, 'budget': None, 'genres': ['57', 'theaters'], 'title': 'Sarah Silverman: Jesus Is Magic'}
# scraping  Undiscovered
# {'domestic': 1069318, 'international': 13466, 'worldwide': 1082784, 'budget': 9000000, 'genres': ['Comedy', 'Music', 'Romance'], 'title': 'Undiscovered'}
# scraping  Santa vs. the Snowman 3D
# {'domestic': 1222538, 'international': None, 'worldwide': 1222538, 'budget': None, 'genres': ['32', 'theaters'], 'title': 'Santa vs. the Snowman 3D'}
# scraping  Paradise Now
# {'domestic': 1457843, 'international': 2122059, 'worldwide': 3579902, 'budget': 2000000, 'genres': ['Crime', 'Drama', 'Thriller', 'War'], 'title': 'Paradise Now'}
# scraping  The Beat That My Heart Skipped
# {'domestic': 1023424, 'international': 9964973, 'worldwide': 10988397, 'budget': None, 'genres': ['37', 'theaters'], 'title': 'The Beat That My Heart Skipped'}
# scraping  Paper Clips
# {'domestic': 1121744, 'international': None, 'worldwide': 1121744, 'budget': None, 'genres': ['403', 'days/57', 'weeks'], 'title': 'Paper Clips'}
# scraping  My Summer of Love
# {'domestic': 1000915, 'international': 1766061, 'worldwide': 2766976, 'budget': None, 'genres': ['198', 'days/28', 'weeks'], 'title': 'My Summer of Love'}
# scraping  Mangal Pandey: The Rising
# {'domestic': 954108, 'international': 7187968, 'worldwide': 8142076, 'budget': None, 'genres': ['63', 'theaters'], 'title': 'Mangal Pandey: The Rising'}
# scraping  Bunty Aur Babli
# {'domestic': 942756, 'international': 2427386, 'worldwide': 3370142, 'budget': None, 'genres': ['51', 'theaters'], 'title': 'Bunty Aur Babli'}
# scraping  Separate Lies
# {'domestic': 924260, 'international': 2527763, 'worldwide': 3452023, 'budget': None, 'genres': ['112', 'days/16', 'weeks'], 'title': 'Separate Lies'}
# scraping  What the #$*! Do We (K)now!?
# {'domestic': 10942306, 'international': 5055872, 'worldwide': 15998178, 'budget': None, 'genres': ['146', 'theaters'], 'title': 'What the #$*! Do We (K)now!?'}
# scraping  Shall We Dance
# {'domestic': 57890460, 'international': 112238000, 'worldwide': 170128460, 'budget': 50000000, 'genres': ['Comedy', 'Drama', 'Music', 'Romance'], 'title': 'Shall We Dance'}
# scraping  Venom
# {'domestic': 881779, 'international': None, 'worldwide': 881779, 'budget': None, 'genres': ['107', 'days/15', 'weeks'], 'title': 'Venom'}
# scraping  Galapagos
# {'domestic': 18630372, 'international': 10718800, 'worldwide': 29349172, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Galapagos'}
# scraping  Where the Truth Lies
# {'domestic': 872142, 'international': 2615536, 'worldwide': 3487678, 'budget': 25000000, 'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'], 'title': 'Where the Truth Lies'}
# scraping  Mirrormask
# ...
# scraping  Ethan Mao
# {'domestic': 10178, 'international': 6266, 'worldwide': 16444, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Ethan Mao'}
# scraping  Gilles' Wife
# {'domestic': 32799, 'international': 234603, 'worldwide': 267402, 'budget': None, 'genres': ['2', 'theaters'], 'title': "Gilles' Wife"}
# scraping  A Talking Picture
# {'domestic': 20237, 'international': 581578, 'worldwide': 601815, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'A Talking Picture'}
# scraping  Finding Home
# {'domestic': 9736, 'international': None, 'worldwide': 9736, 'budget': None, 'genres': ['247', 'days/35', 'weeks'], 'title': 'Finding Home'}
# scraping  The Intruder
# {'domestic': 40853, 'international': None, 'worldwide': 40853, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Intruder'}
# scraping  Enduring Love
# {'domestic': 358362, 'international': 1469822, 'worldwide': 1828184, 'budget': None, 'genres': ['429', 'days/61', 'weeks'], 'title': 'Enduring Love'}
# scraping  Innocence and Experience: The Making of 'The Age of Innocence'
# {'domestic': 9395, 'international': None, 'worldwide': 9395, 'budget': None, 'genres': ['1', 'theater'], 'title': "Innocence and Experience: The Making of 'The Age of Innocence'"}
# scraping  First Love
# {'domestic': 9392, 'international': None, 'worldwide': 9392, 'budget': None, 'genres': ['1', 'theater'], 'title': 'First Love'}
# scraping  Milk and Honey
# {'domestic': 9331, 'international': None, 'worldwide': 9331, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Milk and Honey'}
# scraping  Rosenstrasse
# {'domestic': 734519, 'international': 5341090, 'worldwide': 6075609, 'budget': None, 'genres': ['24', 'theaters'], 'title': 'Rosenstrasse'}
# scraping  Testosterone
# {'domestic': 185078, 'international': 63050, 'worldwide': 248128, 'budget': None, 'genres': ['478', 'days/68', 'weeks'], 'title': 'Testosterone'}
# scraping  Living Life
# {'domestic': 9064, 'international': None, 'worldwide': 9064, 'budget': None, 'genres': ['268', 'days/38', 'weeks'], 'title': 'Living Life'}
# scraping  WMD: Weapons of Mass Deception
# {'domestic': 30210, 'international': None, 'worldwide': 30210, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'WMD: Weapons of Mass Deception'}
# scraping  The Swenkas
# {'domestic': 8860, 'international': None, 'worldwide': 8860, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Swenkas'}
# scraping  Ae Fond Kiss
# {'domestic': 30148, 'international': 6517493, 'worldwide': 6547641, 'budget': None, 'genres': ['401', 'days/57', 'weeks'], 'title': 'Ae Fond Kiss'}
# scraping  Goodbye, Dragon Inn
# {'domestic': 35120, 'international': None, 'worldwide': 35120, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Goodbye, Dragon Inn'}
# scraping  Twist of Faith
# {'domestic': 8129, 'international': None, 'worldwide': 8129, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Twist of Faith'}
# scraping  16 Years of Alcohol
# {'domestic': 8046, 'international': None, 'worldwide': 8046, 'budget': None, 'genres': ['292', 'days/41', 'weeks'], 'title': '16 Years of Alcohol'}
# scraping  The Far Side of the Moon
# {'domestic': 12534, 'international': None, 'worldwide': 12534, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Far Side of the Moon'}
# scraping  Games of Love and Chance
# {'domestic': 8085, 'international': 241531, 'worldwide': 249616, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Games of Love and Chance'}
# scraping  Occupation: Dreamland
# {'domestic': 8018, 'international': None, 'worldwide': 8018, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Occupation: Dreamland'}
# scraping  A Decent Factory
# {'domestic': 7925, 'international': None, 'worldwide': 7925, 'budget': None, 'genres': ['1', 'theater'], 'title': 'A Decent Factory'}
# scraping  L.A. Twister
# {'domestic': 54000, 'international': None, 'worldwide': 54000, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'L.A. Twister'}
# scraping  The Deserted Station
# {'domestic': 18867, 'international': None, 'worldwide': 18867, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Deserted Station'}
# scraping  Daybreak
# {'domestic': 6995, 'international': 22086, 'worldwide': 29081, 'budget': None, 'genres': ['333', 'days/47', 'weeks'], 'title': 'Daybreak'}
# scraping  Aristide and the Endless Revolution
# {'domestic': 6998, 'international': None, 'worldwide': 6998, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Aristide and the Endless Revolution'}
# scraping  Good Morning, Night
# {'domestic': 10093, 'international': 4224562, 'worldwide': 4234655, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Good Morning, Night'}
# scraping  The Aggressives
# {'domestic': 6533, 'international': None, 'worldwide': 6533, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Aggressives'}
# scraping  Santa santita
# {'domestic': 6470, 'international': None, 'worldwide': 6470, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Santa santita'}
# scraping  White King, Red Rubber, Black Death
# {'domestic': 6458, 'international': None, 'worldwide': 6458, 'budget': None, 'genres': ['1', 'theater'], 'title': 'White King, Red Rubber, Black Death'}
# scraping  The President's Last Bang
# {'domestic': 9724, 'international': None, 'worldwide': 9724, 'budget': None, 'genres': ['3', 'theaters'], 'title': "The President's Last Bang"}
# scraping  Marebito
# {'domestic': 13983, 'international': 93276, 'worldwide': 107259, 'budget': None, 'genres': ['388', 'days/55', 'weeks'], 'title': 'Marebito'}
# scraping  Solitude
# {'domestic': 6260, 'international': None, 'worldwide': 6260, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Solitude'}
# scraping  Emile
# {'domestic': 5799, 'international': None, 'worldwide': 5799, 'budget': None, 'genres': ['331', 'days/47', 'weeks'], 'title': 'Emile'}
# scraping  Howard Zinn: You Can't Be Neutral on a Moving Train
# {'domestic': 122011, 'international': None, 'worldwide': 122011, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': "Howard Zinn: You Can't Be Neutral on a Moving Train"}
# scraping  Dream
# {'domestic': 5729, 'international': None, 'worldwide': 5729, 'budget': None, 'genres': ['93', 'days/13', 'weeks'], 'title': 'Dream'}
# scraping  The Roost
# {'domestic': 5642, 'international': None, 'worldwide': 5642, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'The Roost'}
# scraping  Quattro Noza
# {'domestic': 5471, 'international': None, 'worldwide': 5471, 'budget': None, 'genres': ['44', 'days/6', 'weeks'], 'title': 'Quattro Noza'}
# scraping  A Silent Love
# {'domestic': 14389, 'international': None, 'worldwide': 14389, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'A Silent Love'}
# scraping  Peace, Propaganda & the Promised Land
# {'domestic': 4930, 'international': None, 'worldwide': 4930, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Peace, Propaganda & the Promised Land'}
# scraping  Perlasca
# {'domestic': 4780, 'international': None, 'worldwide': 4780, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Perlasca'}
# scraping  Isn't This a Time! A Tribute Concert for Harold Leventhal
# {'domestic': 4683, 'international': None, 'worldwide': 4683, 'budget': None, 'genres': ['1', 'theater'], 'title': "Isn't This a Time! A Tribute Concert for Harold Leventhal"}
# scraping  My Big Fat Independent Movie
# {'domestic': 4655, 'international': 12150594, 'worldwide': 12155249, 'budget': None, 'genres': ['93', 'days/13', 'weeks'], 'title': 'My Big Fat Independent Movie'}
# scraping  Sacred Stage: The Mariinsky Theater
# {'domestic': 4410, 'international': None, 'worldwide': 4410, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Sacred Stage: The Mariinsky Theater'}
# scraping  McLibel
# {'domestic': 4337, 'international': 2113, 'worldwide': 6450, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'McLibel'}
# scraping  This Divided State
# {'domestic': 4255, 'international': None, 'worldwide': 4255, 'budget': None, 'genres': ['1', 'theater'], 'title': 'This Divided State'}
# scraping  The Painting
# {'domestic': 4115, 'international': None, 'worldwide': 4115, 'budget': None, 'genres': ['338', 'days/48', 'weeks'], 'title': 'The Painting'}
# scraping  Silent Waters
# {'domestic': 7384, 'international': None, 'worldwide': 7384, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Silent Waters'}
# scraping  A Hole in My Heart
# {'domestic': 3784, 'international': None, 'worldwide': 3784, 'budget': None, 'genres': ['1', 'theater'], 'title': 'A Hole in My Heart'}
# scraping  The Helix... Loaded
# {'domestic': 3700, 'international': None, 'worldwide': 3700, 'budget': None, 'genres': ['282', 'days/40', 'weeks'], 'title': 'The Helix... Loaded'}
# scraping  Happy Here and Now
# {'domestic': 3574, 'international': None, 'worldwide': 3574, 'budget': None, 'genres': ['23', 'days/3', 'weeks'], 'title': 'Happy Here and Now'}
# scraping  The Rider Named Death
# {'domestic': 3375, 'international': 1334761, 'worldwide': 1338136, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Rider Named Death'}
# scraping  The Inheritance
# {'domestic': 68215, 'international': 574103, 'worldwide': 642318, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Inheritance'}
# scraping  I Love Your Work
# {'domestic': 3264, 'international': None, 'worldwide': 3264, 'budget': None, 'genres': ['63', 'days/9', 'weeks'], 'title': 'I Love Your Work'}
# scraping  Sex Is Comedy
# {'domestic': 40470, 'international': None, 'worldwide': 40470, 'budget': None, 'genres': ['438', 'days/62', 'weeks'], 'title': 'Sex Is Comedy'}
# scraping  Sex Sells: The Making of 'Touché'
# {'domestic': 3252, 'international': None, 'worldwide': 3252, 'budget': None, 'genres': ['310', 'days/44', 'weeks'], 'title': "Sex Sells: The Making of 'Touché'"}
# scraping  Nowhere Man
# {'domestic': 3105, 'international': None, 'worldwide': 3105, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Nowhere Man'}
# scraping  Unveiled
# {'domestic': 3025, 'international': None, 'worldwide': 3025, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Unveiled'}
# scraping  15
# {'domestic': 3013, 'international': None, 'worldwide': 3013, 'budget': None, 'genres': ['1', 'theater'], 'title': '15'}
# scraping  Stolen Childhoods
# {'domestic': 2996, 'international': None, 'worldwide': 2996, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Stolen Childhoods'}
# scraping  Three Days of Rain
# {'domestic': 2841, 'international': None, 'worldwide': 2841, 'budget': None, 'genres': ['93', 'days/13', 'weeks'], 'title': 'Three Days of Rain'}
# scraping  The Beauty Academy of Kabul
# {'domestic': 225448, 'international': None, 'worldwide': 225448, 'budget': None, 'genres': ['13', 'theaters'], 'title': 'The Beauty Academy of Kabul'}
# scraping  The Tracker
# {'domestic': 55188, 'international': None, 'worldwide': 55188, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Tracker'}
# scraping  The Optimists
# {'domestic': 2377, 'international': None, 'worldwide': 2377, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Optimists'}
# scraping  The Overture
# {'domestic': 2254, 'international': 3486, 'worldwide': 5740, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Overture'}
# scraping  Side Effects
# {'domestic': 2216, 'international': None, 'worldwide': 2216, 'budget': 30000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Side Effects'}
# scraping  Anatomy of Hell
# {'domestic': 34506, 'international': 310859, 'worldwide': 345365, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Anatomy of Hell'}
# scraping  Steal Me
# {'domestic': 1967, 'international': None, 'worldwide': 1967, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Steal Me'}
# scraping  With God on Our Side: George W. Bush and the Rise of the Religious Right in America
# {'domestic': 1884, 'international': None, 'worldwide': 1884, 'budget': None, 'genres': ['1', 'theater'], 'title': 'With God on Our Side: George W. Bush and the Rise of the Religious Right in America'}
# scraping  She's One of Us
# {'domestic': 1870, 'international': None, 'worldwide': 1870, 'budget': None, 'genres': ['1', 'theater'], 'title': "She's One of Us"}
# scraping  Electric Shadows
# {'domestic': 7129, 'international': 49680, 'worldwide': 56809, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Electric Shadows'}
# scraping  Das Boot ist voll
# {'domestic': 1718, 'international': None, 'worldwide': 1718, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Das Boot ist voll'}
# scraping  Twin Sisters
# {'domestic': 1563, 'international': 792802, 'worldwide': 794365, 'budget': None, 'genres': ['240', 'days/34', 'weeks'], 'title': 'Twin Sisters'}
# scraping  Making Grace
# {'domestic': 1496, 'international': None, 'worldwide': 1496, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Making Grace'}
# scraping  The Letter: An American Town and the 'Somali Invasion'
# {'domestic': 1479, 'international': None, 'worldwide': 1479, 'budget': None, 'genres': ['1', 'theater'], 'title': "The Letter: An American Town and the 'Somali Invasion'"}
# scraping  Who Killed Bambi?
# {'domestic': 14532, 'international': 958641, 'worldwide': 973173, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Who Killed Bambi?'}
# scraping  Kalyug
# {'domestic': 1435, 'international': None, 'worldwide': 1435, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'Kalyug'}
# scraping  Monumental: David Brower's Fight for Wild America
# {'domestic': 1430, 'international': None, 'worldwide': 1430, 'budget': None, 'genres': ['1', 'theater'], 'title': "Monumental: David Brower's Fight for Wild America"}
# scraping  Return to the Land of Wonders
# {'domestic': 1338, 'international': None, 'worldwide': 1338, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Return to the Land of Wonders'}
# scraping  Proteus: A Nineteenth Century Vision
# {'domestic': 1246, 'international': None, 'worldwide': 1246, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Proteus: A Nineteenth Century Vision'}
# scraping  Uzak
# {'domestic': 96293, 'international': 660715, 'worldwide': 757008, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Uzak'}
# scraping  Two Men Went to War
# {'domestic': 150208, 'international': 66943, 'worldwide': 217151, 'budget': None, 'genres': ['646', 'days/92', 'weeks'], 'title': 'Two Men Went to War'}
# scraping  A Grin Without A Cat
# {'domestic': 43616, 'international': None, 'worldwide': 43616, 'budget': None, 'genres': ['1', 'theater'], 'title': 'A Grin Without A Cat'}
# scraping  The Raspberry Reich
# {'domestic': 31211, 'international': None, 'worldwide': 31211, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Raspberry Reich'}
# scraping  Zelary
# {'domestic': 330033, 'international': 15131272, 'worldwide': 15461305, 'budget': None, 'genres': ['471', 'days/67', 'weeks'], 'title': 'Zelary'}
# scraping  Spooky House
# {'domestic': 637, 'international': None, 'worldwide': 637, 'budget': None, 'genres': ['219', 'days/31', 'weeks'], 'title': 'Spooky House'}
# scraping  L'autre monde
# {'domestic': 2494, 'international': None, 'worldwide': 2494, 'budget': None, 'genres': ['1', 'theater'], 'title': "L'autre monde"}
# scraping  Steve + Sky
# {'domestic': 624, 'international': None, 'worldwide': 624, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Steve + Sky'}
# scraping  The Comedians of Comedy
# {'domestic': 549, 'international': None, 'worldwide': 549, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Comedians of Comedy'}
# scraping  The Dark Hours
# {'domestic': 423, 'international': None, 'worldwide': 423, 'budget': None, 'genres': ['80', 'days/11', 'weeks'], 'title': 'The Dark Hours'}
# scraping  The Brown Bunny
# {'domestic': 366301, 'international': 36298, 'worldwide': 402599, 'budget': None, 'genres': ['19', 'theaters'], 'title': 'The Brown Bunny'}
# scraping  Yes Nurse! No Nurse!
# {'domestic': 13325, 'international': None, 'worldwide': 13325, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Yes Nurse! No Nurse!'}
# scraping  Head in the Clouds
# {'domestic': 398278, 'international': 3112327, 'worldwide': 3510605, 'budget': None, 'genres': ['471', 'days/67', 'weeks'], 'title': 'Head in the Clouds'}

# %%
bom_df_2019 = pd.DataFrame.from_dict(movie_dict_2019,orient="index")
bom_df_2019.head()
# Out:
#                                              domestic  international  \
# /release/rl3698624001/?ref_=bo_yld_table_1  600788188   1.250118e+09
# /release/rl2973926913/?ref_=bo_yld_table_2  201578182   3.521316e+08
# /release/rl3396044289/?ref_=bo_yld_table_3  216540909   2.653000e+08
# /release/rl172000769/?ref_=bo_yld_table_4   176484651   1.934000e+08
# /release/rl2037941761/?ref_=bo_yld_table_5  161491646   2.450000e+07
#
#                                              worldwide       budget  \
# /release/rl3698624001/?ref_=bo_yld_table_1  1850906470  200000000.0
# /release/rl2973926913/?ref_=bo_yld_table_2   553709788  140000000.0
# /release/rl3396044289/?ref_=bo_yld_table_3   481840909   70000000.0
# /release/rl172000769/?ref_=bo_yld_table_4    369884651   23000000.0
# /release/rl2037941761/?ref_=bo_yld_table_5   185991646   23000000.0
#
#                                                                            genres  \
# /release/rl3698624001/?ref_=bo_yld_table_1                       [Drama, Romance]
# /release/rl2973926913/?ref_=bo_yld_table_2  [Action, Adventure, Sci-Fi, Thriller]
# /release/rl3396044289/?ref_=bo_yld_table_3                           [Drama, War]
# /release/rl172000769/?ref_=bo_yld_table_4                       [Comedy, Romance]
# /release/rl2037941761/?ref_=bo_yld_table_5                        [Comedy, Sport]
#
#                                                                    title
# /release/rl3698624001/?ref_=bo_yld_table_1                       Titanic
# /release/rl2973926913/?ref_=bo_yld_table_2                    Armageddon
# /release/rl3396044289/?ref_=bo_yld_table_3           Saving Private Ryan
# /release/rl172000769/?ref_=bo_yld_table_4   There's Something About Mary
# /release/rl2037941761/?ref_=bo_yld_table_5                  The Waterboy

# %%
bom_df_2019.to_csv("zippedData/bom-budget-and-genres-2019.csv")
